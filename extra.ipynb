# %%
import pandas as pd

df = pd.read_csv('articles.csv')
df
# Out:
#                                                  title  \
# 0    Four 50 MP cameras, IP69 and 6,200 mAh battery...
# 1             Oppo A5, A5 5G, and A5x are now official
# 2    WhatsApp Plans to Roll Out Status Forwarding T...
# 3    Engadget Podcast: Who needs Samsung's super-th...
# 4    Best and Used Mobile Phones Under 50,000- Chec...
# ..                                                 ...
# 105  Nearly 100 people killed in Israeli attack on ...
# 106  Trump acknowledges starvation in Gaza as Israe...
# 107  Iran has ‘sort of’ agreed deal on nuclear prog...
# 108  Trump’s Gulf tour: Jumbo jets, megadeals and f...
# 109  Boeing secures ‘largest-ever’ order from Qatar...
#
#                                                   text  \
# 0    Oppo has launched two interesting mid-range sm...
# 1    Oppo has made the A5, A5 5G, and A5x (which le...
# 2    WhatsApp is preparing to give users enhanced c...
# 3    And we dive into Google's latest attempt to ma...
# ...

# %%
world_articles = df['category']=='World'
